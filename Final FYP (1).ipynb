# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA

# Load the dataset
file_path = 'dataset.csv'
data = pd.read_csv(file_path)

# Convert the 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# Set 'Date' as the index
data.set_index('Date', inplace=True)

# Display the first few rows of the dataset and the data types of each column
print(data.head())
print(data.dtypes)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.447412  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.458557  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.355828  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.344077  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.386254  447610800
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# Filter the data to show from start till "30-11-22"
filtered_data = data[:'2022-11-30']

# Plotting the filtered data as a line chart
plt.figure(figsize=(10, 8))
plt.plot(filtered_data['Close'], label='Line Chart of Close Price', color='red')
plt.title('Line Chart of Close Price Trend until November 2022')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # LSTM Model

# %%
# Scaling the data for LSTM model
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data['Close'].values.reshape(-1, 1))

# Prepare the training and validation data for LSTM
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size - 60:]  # Include the last 60 days of training data for context

# Create sequences for training
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(seq_length, len(data)):
        X.append(data[i-seq_length:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

seq_length = 60
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

# Reshape the data to be suitable for LSTM input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))  # Predicting 1 value

model.compile(optimizer='adam', loss='mean_squared_error')

# Train the LSTM model
model.fit(X_train, y_train, epochs=80, batch_size=32, validation_data=(X_test, y_test))
# Out:
# C:\Users\BAHU Computers\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 25s 93ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 2/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - loss: 9.7524e-05 - val_loss: 0.0015
# Epoch 3/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 8.7661e-05 - val_loss: 0.0015
# Epoch 4/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 8.5990e-05 - val_loss: 0.0014
# Epoch 5/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 6.8509e-05 - val_loss: 0.0015
# Epoch 6/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 6.7667e-05 - val_loss: 0.0013
# Epoch 7/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 5.3528e-05 - val_loss: 0.0020
# Epoch 8/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - loss: 5.9881e-05 - val_loss: 0.0042
# Epoch 9/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 4.3909e-05 - val_loss: 0.0020
# Epoch 10/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 5.0243e-05 - val_loss: 0.0021
# Epoch 11/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 4.9251e-05 - val_loss: 0.0025
# Epoch 12/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 5.7886e-05 - val_loss: 0.0026
# Epoch 13/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 4.6280e-05 - val_loss: 0.0037
# Epoch 14/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 4.0771e-05 - val_loss: 0.0025
# Epoch 15/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 4.8431e-05 - val_loss: 0.0017
# Epoch 16/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - loss: 3.9375e-05 - val_loss: 0.0026
# Epoch 17/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 4.6118e-05 - val_loss: 0.0060
# Epoch 18/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - loss: 5.3510e-05 - val_loss: 0.0043
# Epoch 19/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 4.3083e-05 - val_loss: 0.0021
# Epoch 20/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 4.1084e-05 - val_loss: 0.0031
# Epoch 21/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - loss: 4.1163e-05 - val_loss: 0.0023
# Epoch 22/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 3.8696e-05 - val_loss: 0.0028
# Epoch 23/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 3.6540e-05 - val_loss: 0.0034
# Epoch 24/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 4.1758e-05 - val_loss: 0.0020
# Epoch 25/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - loss: 3.8197e-05 - val_loss: 0.0014
# Epoch 26/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 3.1323e-05 - val_loss: 0.0018
# Epoch 27/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 3.3249e-05 - val_loss: 0.0032
# Epoch 28/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - loss: 4.1609e-05 - val_loss: 0.0035
# Epoch 29/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 3.4252e-05 - val_loss: 0.0024
# Epoch 30/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step - loss: 2.9909e-05 - val_loss: 0.0019
# Epoch 31/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 3.0363e-05 - val_loss: 0.0033
# Epoch 32/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 2.9921e-05 - val_loss: 0.0020
# Epoch 33/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 3.1475e-05 - val_loss: 7.5311e-04
# Epoch 34/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 3.1654e-05 - val_loss: 0.0011
# Epoch 35/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - loss: 3.3378e-05 - val_loss: 5.8757e-04
# Epoch 36/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 3.5811e-05 - val_loss: 0.0027
# Epoch 37/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 3.1100e-05 - val_loss: 0.0040
# Epoch 38/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - loss: 4.2459e-05 - val_loss: 0.0022
# Epoch 39/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 2.9673e-05 - val_loss: 0.0019
# Epoch 40/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - loss: 3.1663e-05 - val_loss: 0.0016
# Epoch 41/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - loss: 2.6754e-05 - val_loss: 0.0022
# Epoch 42/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - loss: 2.5134e-05 - val_loss: 0.0017
# Epoch 43/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - loss: 3.2787e-05 - val_loss: 0.0015
# Epoch 44/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 108ms/step - loss: 2.3783e-05 - val_loss: 0.0019
# Epoch 45/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 2.4575e-05 - val_loss: 0.0032
# Epoch 46/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - loss: 2.3999e-05 - val_loss: 0.0015
# Epoch 47/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - loss: 2.8743e-05 - val_loss: 0.0017
# Epoch 48/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - loss: 2.5218e-05 - val_loss: 0.0014
# Epoch 49/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - loss: 2.6761e-05 - val_loss: 0.0021
# Epoch 50/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 2.4169e-05 - val_loss: 0.0025
# Epoch 51/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 3.7231e-05 - val_loss: 0.0025
# Epoch 52/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - loss: 2.4591e-05 - val_loss: 0.0022
# Epoch 53/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 2.2338e-05 - val_loss: 8.0651e-04
# Epoch 54/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - loss: 2.3265e-05 - val_loss: 0.0023
# Epoch 55/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - loss: 2.2930e-05 - val_loss: 0.0032
# Epoch 56/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 2.9488e-05 - val_loss: 0.0029
# Epoch 57/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 2.2389e-05 - val_loss: 0.0018
# Epoch 58/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 2.3223e-05 - val_loss: 0.0016
# Epoch 59/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - loss: 2.0945e-05 - val_loss: 0.0022
# Epoch 60/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.8362e-05 - val_loss: 0.0014
# Epoch 61/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.7024e-05 - val_loss: 0.0017
# Epoch 62/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - loss: 2.5680e-05 - val_loss: 0.0014
# Epoch 63/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - loss: 2.0554e-05 - val_loss: 0.0016
# Epoch 64/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 1.9930e-05 - val_loss: 0.0015
# Epoch 65/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - loss: 2.2491e-05 - val_loss: 7.5035e-04
# Epoch 66/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 1.9487e-05 - val_loss: 7.6802e-04
# Epoch 67/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 2.1420e-05 - val_loss: 0.0015
# Epoch 68/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 2.2806e-05 - val_loss: 0.0015
# Epoch 69/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - loss: 1.9336e-05 - val_loss: 0.0020
# Epoch 70/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 2.1900e-05 - val_loss: 0.0015
# Epoch 71/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.9556e-05 - val_loss: 0.0019
# Epoch 72/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 3.1210e-05 - val_loss: 0.0011
# Epoch 73/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 1.4435e-05 - val_loss: 0.0023
# Epoch 74/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 2.0816e-05 - val_loss: 0.0015
# Epoch 75/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 1.8131e-05 - val_loss: 0.0017
# Epoch 76/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 1.7458e-05 - val_loss: 0.0015
# Epoch 77/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 2.1735e-05 - val_loss: 0.0011
# Epoch 78/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1.6550e-05 - val_loss: 0.0010
# Epoch 79/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 1.5135e-05 - val_loss: 0.0016
# Epoch 80/80
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 2.0222e-05 - val_loss: 0.0011

# %%
# Make predictions on the test data
predicted_scaled = model.predict(X_test)

# Inverse transform to get the actual values
predicted = scaler.inverse_transform(predicted_scaled)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Filter the data for December 2022 only
december_start = '2022-12-01'
december_end = '2022-12-30'
december_mask = (data.index >= december_start) & (data.index <= december_end)

# Filter the actual and predicted values for December 2022
december_dates = data.index[december_mask]
predicted_december = predicted[-len(december_dates):]
y_test_december = y_test_actual[-len(december_dates):]

# Plotting the LSTM predictions vs actual values for December 2022
plt.figure(figsize=(10, 8))
plt.plot(december_dates, y_test_december, label='Actual Close Price', color='red', marker='o')
plt.plot(december_dates, predicted_december, label='LSTM Predicted Close Price', color='green', marker='o')
plt.title('LSTM Model - Actual vs Predicted Close Prices for December 2022')
plt.xlabel('Date')
plt.ylabel('Close Price')

# Format the x-axis to display only date and month
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%b'))
plt.xticks(rotation=45)  # Rotate the labels for better visibility

# Fill between for a clearer comparison
plt.fill_between(december_dates, y_test_december.flatten(), predicted_december.flatten(), 
                 color='gray', alpha=0.2, label='Difference')

plt.legend()
plt.grid(True)
plt.show()
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step

# %% [markdown]
# # ARIMA Model

# %%
# Fit the ARIMA model
arima_model = ARIMA(data['Close'], order=(5, 1, 0))    #   autoregressive terms (AR), 1 differencing term (I), and 0 moving average terms (MA)
arima_model_fit = arima_model.fit()

# Create a future dataframe for December 2022 for ARIMA
start = '2022-12-01'
end = '2022-12-30'
arima_forecast = arima_model_fit.predict(start=start, end=end, dynamic=False)
# Out:
# C:\Users\BAHU Computers\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\BAHU Computers\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\BAHU Computers\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Plotting the ARIMA predictions vs actual values for December 2022
plt.figure(figsize=(10, 8))
plt.plot(arima_forecast.index, arima_forecast, label='ARIMA Predicted Close Price', color='blue', marker='o')
plt.plot(december_dates, data['Close'][december_mask], label='Actual Close Price', color='red', marker='o')
plt.title('ARIMA Model - Actual vs Predicted Close Prices for December 2022')
plt.xlabel('Date')
plt.ylabel('Close Price')

# Format the x-axis to display only date and month
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%b'))
plt.xticks(rotation=45)  # Rotate the labels for better visibility

# Fill between for a clearer comparison
plt.fill_between(arima_forecast.index, data['Close'][december_mask], arima_forecast, 
                 color='gray', alpha=0.2, label='Difference')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Comparison of Actual and Predicted Values

# %%
# Assuming 'data' is your original DataFrame with the date index and 'Close' column
# Filter the actual close prices for December 2022
december_mask = (data.index >= '2022-12-01') & (data.index <= '2022-12-30')
actual_dec_2022 = data.loc[december_mask]

# Merge actual and ARIMA predictions for December 2022
combined_df = actual_dec_2022[['Close']].join(arima_forecast.rename('ARIMA'), how='inner')

# Adding LSTM predictions to the combined DataFrame
combined_df['LSTM'] = predicted_december  # Make sure this variable has the predictions for December

# Plotting the combined data
plt.figure(figsize=(10, 8))
plt.plot(combined_df.index, combined_df['Close'], label='Actual Close Price', color='red', marker='o')
plt.plot(combined_df.index, combined_df['ARIMA'], label='ARIMA Predicted Close Price', color='blue', marker='o')
plt.plot(combined_df.index, combined_df['LSTM'], label='LSTM Predicted Close Price', color='purple', marker='o')
plt.title('Actual vs ARIMA and LSTM Predicted Close Prices for December 2022')
plt.xlabel('Date')
plt.ylabel('Close Price')

# Format the x-axis to display only date and month
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%b'))
plt.xticks(rotation=45)  # Rotate the labels for better visibility

plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate and display error metrics for LSTM model for December 2022
mse_lstm = mean_squared_error(actual_dec_2022['Close'], combined_df['LSTM'])
mae_lstm = mean_absolute_error(actual_dec_2022['Close'], combined_df['LSTM'])

print(f'LSTM Mean Squared Error for December 2022: {mse_lstm}')
print(f'LSTM Mean Absolute Error for December 2022: {mae_lstm}')

# Calculate and display error metrics for ARIMA model for December 2022
mse_arima = mean_squared_error(actual_dec_2022['Close'], combined_df['ARIMA'])
mae_arima = mean_absolute_error(actual_dec_2022['Close'], combined_df['ARIMA'])

print(f'ARIMA Mean Squared Error for December 2022: {mse_arima}')
print(f'ARIMA Mean Absolute Error for December 2022: {mae_arima}')
# Out:
# LSTM Mean Squared Error for December 2022: 20.069253330631735
# LSTM Mean Absolute Error for December 2022: 3.849536350795201
# ARIMA Mean Squared Error for December 2022: 6.770314563302021
# ARIMA Mean Absolute Error for December 2022: 2.072930182572737
